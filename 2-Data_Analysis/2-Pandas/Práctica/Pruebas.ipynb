# %%
import numpy as np
import pandas as pd

# %%
my_dict = {
    'edad': [23, 24, 25, 26, 27],
    'nombre': ['Pablo', 'Marcos', 'Tomás', 'Maxi', 'Omar'],
    'peso': [73, 74, 75, 76, 77],
    'estatura': [1.76, 1.77, 1.77, 1.78, 2.07],
    'guapo': [True, True, True, True, True]
}

df = pd.DataFrame(my_dict)
df
# Out:
#    edad  nombre  peso  estatura  guapo
# 0    23   Pablo    73      1.76   True
# 1    24  Marcos    74      1.77   True
# 2    25   Tomás    75      1.77   True
# 3    26    Maxi    76      1.78   True
# 4    27    Omar    77      2.07   True

# %%
df['edad'] > 24
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: edad, dtype: bool

# %%
df.loc[:, 'edad']
# Out:
# 0    23
# 1    24
# 2    25
# 3    26
# 4    27
# Name: edad, dtype: int64

# %%
df.iloc[:,0]
# Out:
# 0    23
# 1    24
# 2    25
# 3    26
# 4    27
# Name: edad, dtype: int64

# %%
mask = df.loc[:, 'edad'] > 24
df.loc[mask, 'edad']
# Out:
# 2    25
# 3    26
# 4    27
# Name: edad, dtype: int64

# %%
df.loc[:,['edad', 'guapo']]
# Out:
#    edad  guapo
# 0    23   True
# 1    24   True
# 2    25   True
# 3    26   True
# 4    27   True

# %%
mask = (df.loc[:,'edad'] > 24) & (df.loc[:,'estatura']>1.77)
df.loc[mask, ['nombre', 'guapo', 'edad']]
# Out:
#   nombre  guapo  edad
# 3   Maxi   True    26
# 4   Omar   True    27

# %%
edades_pares = []

for index,row in df.iterrows():
    print(index)
    print(row)
# Out:
# 0
# edad           23
# nombre      Pablo
# peso           73
# estatura     1.76
# guapo        True
# Name: 0, dtype: object
# 1
# edad            24
# nombre      Marcos
# peso            74
# estatura      1.77
# guapo         True
# Name: 1, dtype: object
# 2
# edad           25
# nombre      Tomás
# peso           75
# estatura     1.77
# guapo        True
# Name: 2, dtype: object
# 3
# edad          26
# nombre      Maxi
# peso          76
# estatura    1.78
# guapo       True
# Name: 3, dtype: object
# 4
# edad          27
# nombre      Omar
# peso          77
# estatura    2.07
# guapo       True
# Name: 4, dtype: object

# %%
estaturas_altas = []

for index, row in df.iterrows():
    if (row['estatura']) < 2.0:
        estaturas_altas.append(row['estatura'])

print(estaturas_altas)
# Out:
# [1.76, 1.77, 1.77, 1.78]

# %%
df.describe().T
# Out:
#           count   mean       std    min    25%    50%    75%    max
# edad        5.0  25.00  1.581139  23.00  24.00  25.00  26.00  27.00
# peso        5.0  75.00  1.581139  73.00  74.00  75.00  76.00  77.00
# estatura    5.0   1.83  0.134350   1.76   1.77   1.77   1.78   2.07

# %%
df = pd.read_csv('https://raw.githubusercontent.com/JLGOrtega/DataScienceDatasets/refs/heads/main/datasets/ds_salaries.csv')
df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
df.groupby('company_location')[['salary_in_usd']].mean()
# Out:
#                   salary_in_usd
# company_location
# AE                100000.000000
# AL                 10000.000000
# AM                 50000.000000
# AR                 25000.000000
# AS                 29351.000000
# ...                         ...
# TH                 23064.333333
# TR                 19058.000000
# UA                 57850.000000
# US                151822.009539
# VN                 12000.000000
#
# [72 rows x 1 columns]

# %%
df.groupby('company_location')[['salary_in_usd']].mean().sort_values('salary_in_usd', ascending=False)
# Out:
#                   salary_in_usd
# company_location
# IL                271446.500000
# PR                167500.000000
# US                151822.009539
# RU                140333.333333
# CA                131917.689655
# ...                         ...
# VN                 12000.000000
# AL                 10000.000000
# MA                 10000.000000
# BO                  7500.000000
# MK                  6304.000000
#
# [72 rows x 1 columns]

# %%
df.groupby('company_location')[['salary_in_usd']].mean().sort_values('salary_in_usd', ascending=False).head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='company_location'>

# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = sns.load_dataset('planets')
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
# Vamos a coger el periodo orbital, solo la parte enter y dejar a true si es par o a False si es impar

# %%
PO_PAR = []
for index, row in df.iterrows():
    if pd.isna(row['orbital_period']):
        print('hola')
        PO_PAR.append(np.nan)
        continue
    
    numerito_int = int(row['orbital_period']) 
    if numerito_int %2 == 0:
        PO_PAR.append(True)
    else:
        PO_PAR.append(False)

PO_PAR
# Out:
# [False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  nan,
#  nan,
#  nan,
#  True,
#  nan,
#  nan,
#  nan,
#  nan,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  nan,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  nan,
#  nan,
#  nan,
#  False,
#  nan,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  nan,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
# ...

# %%
def popar(orbita):
    if pd.isna(orbita):
        return np.nan
    if int(orbita) %2 == 0:
        return True
    else:
        return False

# %%
df.loc[:, 'orbital_period'].apply(popar)
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1030    False
# 1031     True
# 1032    False
# 1033     True
# 1034     True
# Name: orbital_period, Length: 1035, dtype: object

# %%
def abreviatura(method):
    palabras = method.split()
    abrv = ''
    for palabra in palabras:
        abrv += palabra[0]
    return abrv

abreviatura('Hola Pablo')

df.loc[:,'method'].apply(abreviatura)
# Out:
# 0       RV
# 1       RV
# 2       RV
# 3       RV
# 4       RV
#         ..
# 1030     T
# 1031     T
# 1032     T
# 1033     T
# 1034     T
# Name: method, Length: 1035, dtype: object

# %%
df.loc[:,'method'].apply(len)
# Out:
# 0       15
# 1       15
# 2       15
# 3       15
# 4       15
#         ..
# 1030     7
# 1031     7
# 1032     7
# 1033     7
# 1034     7
# Name: method, Length: 1035, dtype: int64

# %%
import geopy

# %%
geolocalizador = geopy.Nominatim(user_agent='Tutorial')
geolocalizador.geocode('46011, Spain')
# Out:
# Location(46011, Poblats Marítims, València, Comarca de València, València / Valencia, Comunitat Valenciana, España, (39.4703841, -0.3302586, 0.0))

# %%
def encuentra_zipcode(direccion):
    for index, char in enumerate(direccion):
        if char.isdigit():
            if direccion[index:index + 5].isdigit():
                return direccion[index:index + 5]

# %%
def geolocaliza_zipcode(zip_code):
    geolocalizador = geopy.Nominatim(user_agent='Tutorial')
    respuesta = geolocalizador.geocode(f'{zip_code}, Spain')
    return respuesta.raw['lat'], respuesta.raw['lon']

def geo_address(address):
    return geolocaliza_zipcode(encuentra_zipcode(address))

# %%
geo_address('46910, Spain')
# Out:
# ('39.4229496', '-0.3918375')

# %%
masdos = lambda x: x+2 # Se utiliza para hacer funciones de una línea
# Forma equivalente
def masdos(x):
    return x+2
# Out:
# <function __main__.<lambda>(x)>

# %%
direcciones.loc[:,'addresses'].apply(lambda x: x.replace(',','').lower() )

# %%
 import re

# %%
re.findall??
# Out:
# Signature: re.findall(pattern, string, flags=0)
# Source:
# def findall(pattern, string, flags=0):
#     """Return a list of all non-overlapping matches in the string.
#
#     If one or more capturing groups are present in the pattern, return
#     a list of groups; this will be a list of tuples if the pattern
#     has more than one group.
#
#     Empty matches are included in the result."""
#     return _compile(pattern, flags).findall(string)
# File:      c:\users\pablo\miniconda3\envs\data_analysis_env\lib\re\__init__.py
# Type:      function

# %%
string = """ 
144545210145200
Hola
HOLA
HoLa
jose
jose@gmail.com
pap@gmail.es
            JOSE@GMAIL.COM
adas"""


pattern = '[A-Za-z0-9_]*@[A-Za-z]*.[A-Za-z]+ '
pattern = '\w+@\w+*.\w+ '
pattern = '\s[0-9]{2}\.?[0-9]{3}\s'
re.findall(pattern, string)
# Out:
# []
